# %% [markdown]
# ---
# title: "About"
# ---
#
# This is a jupyter notebook test with a python plot printed.

# %% [markdown]
# # Section 1
# ## Section 1.1
# ### Section 1.1.1

# %%
from matplotlib import pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y)

plt.title("Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
